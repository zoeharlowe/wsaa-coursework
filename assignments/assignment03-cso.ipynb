# %% [markdown]
# # assignment03-cso.ipynb

# %% [markdown]
# This Jupyter Notebook will retrieve the dataset for the "exchequer account (historical series)" from the CSO, and stores it into a file called "cso.json".
#
# Author: Zoe McNamara Harlowe

# %% [markdown]
# ## Imports

# %%
import requests
import json

# %%
url = "https://ws.cso.ie/public/api.restful/PxStat.Data.Cube_API.ReadDataset/FIQ02/JSON-stat/2.0/en"

# %%
def getall():
    response = requests.get(url)
    return response.json()

# %%
if __name__ == "__main__":
    with open("cso.json", "wt") as fp:
        print(json.dumps(getall(), file=fp))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 if __name__ == "__main__":
#       2     with open("cso.json", "wt") as fp:
# ----> 3         print(json.dumps(getall(), file=fp))
#
# File c:\Users\ZMH\anaconda33\Lib\json\__init__.py:234, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     232 if cls is None:
#     233     cls = JSONEncoder
# --> 234 return cls(
#     235     skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236     check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237     separators=separators, default=default, sort_keys=sort_keys,
#     238     **kw).encode(obj)
#
# TypeError: JSONEncoder.__init__() got an unexpected keyword argument 'file'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
